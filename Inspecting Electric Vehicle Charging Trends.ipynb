# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("All Libraries Imported Sucssfully")
# Out:
# All Libraries Imported Sucssfully

# %%
ev_charging_df = pd.read_csv("D:\Inspecting Electric Vehicle Charging trends\Electrical-Vehicle-Usage-Patterns-main\ev_charging_patterns.csv")
ev_charging_df
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0        User_1        BMW i3              108.463007         Station_391
# 1        User_2  Hyundai Kona              100.000000         Station_428
# 2        User_3    Chevy Bolt               75.000000         Station_181
# 3        User_4  Hyundai Kona               50.000000         Station_327
# 4        User_5  Hyundai Kona               50.000000         Station_108
# ...         ...           ...                     ...                 ...
# 1315  User_1316   Nissan Leaf              100.000000          Station_57
# 1316  User_1317        BMW i3              100.000000          Station_40
# 1317  User_1318   Nissan Leaf              100.000000         Station_374
# 1318  User_1319    Chevy Bolt               85.000000         Station_336
# 1319  User_1320   Nissan Leaf              120.447195         Station_128
#
#      Charging Station Location  Charging Start Time    Charging End Time  \
# ...

# %% [markdown]
# # Sample Data

# %%
ev_charging_df.sample(5)
# Out:
#         User ID  Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 566    User_567     Chevy Bolt               85.000000         Station_172
# 931    User_932  Tesla Model 3              143.209995         Station_213
# 1144  User_1145   Hyundai Kona              179.013058          Station_82
# 610    User_611  Tesla Model 3               75.000000         Station_259
# 40      User_41         BMW i3               79.799204         Station_410
#
#      Charging Station Location  Charging Start Time    Charging End Time  \
# 566                    Houston  2024-01-24 14:00:00  2024-01-24 15:10:00
# 931                    Chicago  2024-02-08 19:00:00  2024-02-08 22:04:00
# 1144               Los Angeles  2024-02-17 16:00:00  2024-02-17 18:33:00
# 610              San Francisco  2024-01-26 10:00:00  2024-01-26 13:07:00
# 40                 Los Angeles  2024-01-02 16:00:00  2024-01-02 18:58:00
#
# ...

# %% [markdown]
# # Top and Last 10 Records

# %%
ev_charging_df.head(10)
# Out:
#    User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0   User_1        BMW i3              108.463007         Station_391
# 1   User_2  Hyundai Kona              100.000000         Station_428
# 2   User_3    Chevy Bolt               75.000000         Station_181
# 3   User_4  Hyundai Kona               50.000000         Station_327
# 4   User_5  Hyundai Kona               50.000000         Station_108
# 5   User_6   Nissan Leaf               50.000000         Station_335
# 6   User_7    Chevy Bolt               85.000000         Station_162
# 7   User_8    Chevy Bolt               75.000000         Station_302
# 8   User_9    Chevy Bolt               62.000000         Station_493
# 9  User_10  Hyundai Kona               50.000000         Station_452
#
#   Charging Station Location  Charging Start Time    Charging End Time  \
# 0                   Houston  2024-01-01 00:00:00  2024-01-01 00:39:00
# ...

# %%
ev_charging_df.tail(10)
# Out:
#         User ID  Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 1310  User_1311  Tesla Model 3               62.000000         Station_268
# 1311  User_1312   Hyundai Kona               50.000000          Station_13
# 1312  User_1313    Nissan Leaf               75.000000         Station_120
# 1313  User_1314  Tesla Model 3              129.350616         Station_458
# 1314  User_1315   Hyundai Kona               50.000000         Station_353
# 1315  User_1316    Nissan Leaf              100.000000          Station_57
# 1316  User_1317         BMW i3              100.000000          Station_40
# 1317  User_1318    Nissan Leaf              100.000000         Station_374
# 1318  User_1319     Chevy Bolt               85.000000         Station_336
# 1319  User_1320    Nissan Leaf              120.447195         Station_128
#
#      Charging Station Location  Charging Start Time    Charging End Time  \
# ...

# %% [markdown]
# # Information of the Data

# %%
ev_charging_df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   User ID                                   1320 non-null   object
#  1   Vehicle Model                             1320 non-null   object
#  2   Battery Capacity (kWh)                    1320 non-null   float64
#  3   Charging Station ID                       1320 non-null   object
#  4   Charging Station Location                 1320 non-null   object
#  5   Charging Start Time                       1320 non-null   object
#  6   Charging End Time                         1320 non-null   object
#  7   Energy Consumed (kWh)                     1254 non-null   float64
#  8   Charging Duration (hours)                 1320 non-null   float64
#  9   Charging Rate (kW)                        1254 non-null   float64
# ...

# %% [markdown]
# # Description of the Data

# %%
ev_charging_df.describe()
# Out:
#        Battery Capacity (kWh)  Energy Consumed (kWh)  \
# count             1320.000000            1254.000000
# mean                74.534692              42.642894
# std                 20.626914              22.411705
# min                  1.532807               0.045772
# 25%                 62.000000              23.881193
# 50%                 75.000000              42.691405
# 75%                 85.000000              61.206218
# max                193.003074             152.238758
#
#        Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD)  \
# count                1320.000000         1254.000000          1320.000000
# mean                    2.269377           25.963003            22.551352
# std                     1.061037           14.011326            10.751494
# min                     0.095314            1.472549             0.234317
# 25%                     1.397623           13.856583            13.368141
# ...

# %% [markdown]
# # Checking Null Values

# %%
ev_charging_df[ev_charging_df.isnull().any(axis=1)]
# Out:
#         User ID  Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 21      User_22   Hyundai Kona               62.000000         Station_485
# 28      User_29         BMW i3               75.000000         Station_129
# 30      User_31     Chevy Bolt              100.000000         Station_239
# 44      User_45    Nissan Leaf               75.000000          Station_44
# 48      User_49    Nissan Leaf               85.000000         Station_463
# ...         ...            ...                     ...                 ...
# 1281  User_1282    Nissan Leaf               50.000000         Station_489
# 1284  User_1285   Hyundai Kona               63.990544          Station_77
# 1303  User_1304   Hyundai Kona               81.062030         Station_103
# 1310  User_1311  Tesla Model 3               62.000000         Station_268
# 1312  User_1313    Nissan Leaf               75.000000         Station_120
#
# ...

# %% [markdown]
# # Calculating null values for each colummns

# %%
null_values_for_each_column = ev_charging_df.isna().sum()
null_values_for_each_column#
# Out:
# User ID                                      0
# Vehicle Model                                0
# Battery Capacity (kWh)                       0
# Charging Station ID                          0
# Charging Station Location                    0
# Charging Start Time                          0
# Charging End Time                            0
# Energy Consumed (kWh)                       66
# Charging Duration (hours)                    0
# Charging Rate (kW)                          66
# Charging Cost (USD)                          0
# Time of Day                                  0
# Day of Week                                  0
# State of Charge (Start %)                    0
# State of Charge (End %)                      0
# Distance Driven (since last charge) (km)    66
# Temperature (°C)                             0
# Vehicle Age (years)                          0
# Charger Type                                 0
# User Type                                    0
# dtype: int64

# %% [markdown]
# # Filling the null values with mean of itself column

# %%
ev_charging_df = ev_charging_df.apply(lambda col: col.fillna(col.mean()) if col.dtype in ['float64','int64'] else col)

# %%
ev_charging_df
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0        User_1        BMW i3              108.463007         Station_391
# 1        User_2  Hyundai Kona              100.000000         Station_428
# 2        User_3    Chevy Bolt               75.000000         Station_181
# 3        User_4  Hyundai Kona               50.000000         Station_327
# 4        User_5  Hyundai Kona               50.000000         Station_108
# ...         ...           ...                     ...                 ...
# 1315  User_1316   Nissan Leaf              100.000000          Station_57
# 1316  User_1317        BMW i3              100.000000          Station_40
# 1317  User_1318   Nissan Leaf              100.000000         Station_374
# 1318  User_1319    Chevy Bolt               85.000000         Station_336
# 1319  User_1320   Nissan Leaf              120.447195         Station_128
#
#      Charging Station Location  Charging Start Time    Charging End Time  \
# ...

# %% [markdown]
# # Checking Whether any null values remains or not

# %%
ev_charging_df.isna().sum()
# Out:
# User ID                                     0
# Vehicle Model                               0
# Battery Capacity (kWh)                      0
# Charging Station ID                         0
# Charging Station Location                   0
# Charging Start Time                         0
# Charging End Time                           0
# Energy Consumed (kWh)                       0
# Charging Duration (hours)                   0
# Charging Rate (kW)                          0
# Charging Cost (USD)                         0
# Time of Day                                 0
# Day of Week                                 0
# State of Charge (Start %)                   0
# State of Charge (End %)                     0
# Distance Driven (since last charge) (km)    0
# Temperature (°C)                            0
# Vehicle Age (years)                         0
# Charger Type                                0
# User Type                                   0
# dtype: int64

# %% [markdown]
# # Convert Charging Start Time and Charging End Time data type from Object to DateTime

# %%
ev_charging_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   User ID                                   1320 non-null   object
#  1   Vehicle Model                             1320 non-null   object
#  2   Battery Capacity (kWh)                    1320 non-null   float64
#  3   Charging Station ID                       1320 non-null   object
#  4   Charging Station Location                 1320 non-null   object
#  5   Charging Start Time                       1320 non-null   object
#  6   Charging End Time                         1320 non-null   object
#  7   Energy Consumed (kWh)                     1320 non-null   float64
#  8   Charging Duration (hours)                 1320 non-null   float64
#  9   Charging Rate (kW)                        1320 non-null   float64
# ...

# %%
ev_charging_df['Charging Start Time'] = pd.to_datetime(ev_charging_df['Charging Start Time'])
ev_charging_df['Charging End Time'] = pd.to_datetime(ev_charging_df['Charging End Time'])

print(ev_charging_df['Charging Start Time'].dtype)
print(ev_charging_df['Charging End Time'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
ev_charging_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   User ID                                   1320 non-null   object
#  1   Vehicle Model                             1320 non-null   object
#  2   Battery Capacity (kWh)                    1320 non-null   float64
#  3   Charging Station ID                       1320 non-null   object
#  4   Charging Station Location                 1320 non-null   object
#  5   Charging Start Time                       1320 non-null   datetime64[ns]
#  6   Charging End Time                         1320 non-null   datetime64[ns]
#  7   Energy Consumed (kWh)                     1320 non-null   float64
#  8   Charging Duration (hours)                 1320 non-null   float64
#  9   Charging Rate (kW)                        1320 non-null   float64
# ...

# %% [markdown]
# # Size of dataset (total rows and columns)

# %%
ev_charging_df.shape
# Out:
# (1320, 20)

# %% [markdown]
# # Rounding Float Values to Two Decimal Places

# %%
ev_charging_df = ev_charging_df.apply(lambda col: col.round(2) if col.dtype == 'float64' else col)
ev_charging_df.select_dtypes(include='float64')
# Out:
#       Battery Capacity (kWh)  Energy Consumed (kWh)  \
# 0                     108.46                  60.71
# 1                     100.00                  12.34
# 2                      75.00                  19.13
# 3                      50.00                  79.46
# 4                      50.00                  19.63
# ...                      ...                    ...
# 1315                  100.00                  42.01
# 1316                  100.00                  68.19
# 1317                  100.00                  18.90
# 1318                   85.00                  13.76
# 1319                  120.45                  63.65
#
#       Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD)  \
# 0                          0.59               36.39                13.09
# 1                          3.13               30.68                21.13
# 2                          2.45               27.51                35.67
# ...

# %% [markdown]
# # Converting Vehicle(Age) data type from Float Values to Integers with Standard Rounding

# %%
ev_charging_df['Vehicle Age (years)'] = ev_charging_df['Vehicle Age (years)'].round().astype(int)
ev_charging_df['Vehicle Age (years)'].unique()
# Out:
# array([ 2,  3,  1,  0,  4,  7,  6,  5,  8, 11,  9, 12])

# %%
ev_charging_df
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0        User_1        BMW i3                  108.46         Station_391
# 1        User_2  Hyundai Kona                  100.00         Station_428
# 2        User_3    Chevy Bolt                   75.00         Station_181
# 3        User_4  Hyundai Kona                   50.00         Station_327
# 4        User_5  Hyundai Kona                   50.00         Station_108
# ...         ...           ...                     ...                 ...
# 1315  User_1316   Nissan Leaf                  100.00          Station_57
# 1316  User_1317        BMW i3                  100.00          Station_40
# 1317  User_1318   Nissan Leaf                  100.00         Station_374
# 1318  User_1319    Chevy Bolt                   85.00         Station_336
# 1319  User_1320   Nissan Leaf                  120.45         Station_128
#
#      Charging Station Location Charging Start Time   Charging End Time  \
# ...

# %% [markdown]
# # Create a New Charging Duration Column from inefficient values

# %%
ev_charging_df.sample(5)

charging_start_time = ev_charging_df['Charging Start Time']
charging_end_time = ev_charging_df['Charging End Time']
ev_charging_df['Calculated Duration Time(Hour)'] = ((ev_charging_df['Charging End Time'] - ev_charging_df['Charging Start Time']).dt.total_seconds() / 3600).round(2)
ev_charging_df['Calculated Duration Time(Hour)']
# Out:
# 0       0.65
# 1       2.02
# 2       2.80
# 3       3.70
# 4       1.77
#         ...
# 1315    1.50
# 1316    0.73
# 1317    2.05
# 1318    1.33
# 1319    0.93
# Name: Calculated Duration Time(Hour), Length: 1320, dtype: float64

# %%
ev_charging_df
# Out:
#         User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0        User_1        BMW i3                  108.46         Station_391
# 1        User_2  Hyundai Kona                  100.00         Station_428
# 2        User_3    Chevy Bolt                   75.00         Station_181
# 3        User_4  Hyundai Kona                   50.00         Station_327
# 4        User_5  Hyundai Kona                   50.00         Station_108
# ...         ...           ...                     ...                 ...
# 1315  User_1316   Nissan Leaf                  100.00          Station_57
# 1316  User_1317        BMW i3                  100.00          Station_40
# 1317  User_1318   Nissan Leaf                  100.00         Station_374
# 1318  User_1319    Chevy Bolt                   85.00         Station_336
# 1319  User_1320   Nissan Leaf                  120.45         Station_128
#
#      Charging Station Location Charging Start Time   Charging End Time  \
# ...

# %%
# ev_charging_df.drop('Claculated Duration Time(Hour)',axis=1)

# %% [markdown]
# # Grouping the Vehicle Age(In Years) to analyze patterns and age wise trends

# %%
def group_vehicle_age(vehicle_age):
    if vehicle_age <= 2:
        return "0-2"
    elif vehicle_age <= 5:
        return "3-5"
    else:
        return "More than 5"
    
ev_charging_df['Vehicle Age Group'] = ev_charging_df['Vehicle Age (years)'].apply(group_vehicle_age)

ev_charging_df[['Vehicle Model','Vehicle Age (years)','Vehicle Age Group']]
# Out:
#      Vehicle Model  Vehicle Age (years) Vehicle Age Group
# 0           BMW i3                    2               0-2
# 1     Hyundai Kona                    3               3-5
# 2       Chevy Bolt                    2               0-2
# 3     Hyundai Kona                    1               0-2
# 4     Hyundai Kona                    1               0-2
# ...            ...                  ...               ...
# 1315   Nissan Leaf                    7       More than 5
# 1316        BMW i3                    4               3-5
# 1317   Nissan Leaf                    5               3-5
# 1318    Chevy Bolt                    5               3-5
# 1319   Nissan Leaf                    5               3-5
#
# [1320 rows x 3 columns]

# %% [markdown]
# # Model wise total vehicle

# %%
distribution_of_vehicle_model = ev_charging_df['Vehicle Model'].value_counts().reset_index()
distribution_of_vehicle_model
# Out:
#    Vehicle Model  count
# 0  Tesla Model 3    280
# 1   Hyundai Kona    266
# 2    Nissan Leaf    260
# 3         BMW i3    258
# 4     Chevy Bolt    256

# %% [markdown]
# # Percentage of vehicle by Car Model using Pie Chart

# %%
plt.figure(figsize=(6, 6))  # Adjust size for better symmetry

labels = distribution_of_vehicle_model['Vehicle Model']
sizes = distribution_of_vehicle_model['count']

# Explode the first slice (Tesla Model 3) for emphasis
explode = [0.1 if i == 0 else 0 for i in range(len(labels))]

plt.pie(
    sizes,
    labels=labels,
    autopct='%1.2f%%',
    explode=explode,
    shadow=True,
    startangle=140
)

plt.title(
    "Distribution of Car Model",
    fontdict={'fontsize': 20, 'fontweight': 'bold', 'fontstyle': 'italic'},
    color='hotpink'
)
plt.axis('equal')  # Make sure pie is drawn as a circle
plt.show()

# %% [markdown]
# # Distribution/ Counts of Charging Station Location State Wise

# %%
distribution_of_charging_station_location =  ev_charging_df['Charging Station Location'].value_counts().reset_index(name='Total Station')
distribution_of_charging_station_location
# Out:
#   Charging Station Location  Total Station
# 0               Los Angeles            297
# 1             San Francisco            264
# 2                   Houston            262
# 3                  New York            255
# 4                   Chicago            242

# %% [markdown]
# # Distribution/ Counts of Charging Station Location State using Bar Chart

# %%
plt.figure(figsize=(8,5))
plt.bar(distribution_of_charging_station_location["Charging Station Location"],distribution_of_charging_station_location["Total Station"],color=["cyan","red","hotpink","yellow","green"])
plt.xlabel("Charging Station Location")
plt.ylabel("Total Stations")
plt.title("Distribution of Charging Station Location (State Wise)",color="Blue",fontsize="15",fontweight="bold")
plt.xticks(rotation=45) # rotate name label of x axis
plt.show()

# %% [markdown]
# # Distribution of Charger Type

# %%
distribution_Charger_Type = ev_charging_df['Charger Type'].value_counts().reset_index()
distribution_Charger_Type
# Out:
#       Charger Type  count
# 0          Level 1    459
# 1          Level 2    431
# 2  DC Fast Charger    430

# %%
plt.figure(figsize=(8, 5))
plt.barh(distribution_Charger_Type['Charger Type'], 
         distribution_Charger_Type['count'], 
         color=["yellow","green","lightgreen"])
plt.xlabel('Count')
plt.ylabel('Charger Type')
plt.title('Distribution of Charger Types')
plt.gca().invert_yaxis()  # Optional: keeps the highest bar at the top
plt.show()

# %% [markdown]
# # ANALYSIS BY VEHICLE MODEL

# %%
plt.figure(figsize=(6, 6))  # Adjust size for better symmetry

labels = distribution_of_vehicle_model['Vehicle Model']
sizes = distribution_of_vehicle_model['count']

plt.pie(
    sizes,
    labels=labels,
    autopct='%1.2f%%',
    startangle=140,
    explode=[0.04,0.04,0.04,0.04,0.04],
    shadow=True
)

plt.title(
    "Analysis of Vehicle Model",
    fontdict={'fontsize': 20, 'fontweight': 'bold', 'fontstyle': 'italic'},
    color='blue'
)
plt.axis('equal')  # Make sure pie is drawn as a circle
plt.show()

# %% [markdown]
# # Average battery capacity (kWh) for each vehicle model

# %%
average_Battery_Capacity_by_Car_Model = (ev_charging_df.groupby('Vehicle Model')['Battery Capacity (kWh)'].mean()).round(2).sort_values().reset_index()
average_Battery_Capacity_by_Car_Model
# Out:
#    Vehicle Model  Battery Capacity (kWh)
# 0    Nissan Leaf                   72.84
# 1  Tesla Model 3                   73.80
# 2     Chevy Bolt                   73.91
# 3   Hyundai Kona                   75.40
# 4         BMW i3                   76.78

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,4.5))

bar_plot = sns.barplot(x='Vehicle Model',y='Battery Capacity (kWh)',data=average_Battery_Capacity_by_Car_Model,palette='Reds_d')

for index,row in average_Battery_Capacity_by_Car_Model.iterrows():
    bar_plot.text(row.name, row['Battery Capacity (kWh)'] + 2, round(row['Battery Capacity (kWh)'], 1), color='black', ha="center", fontweight='bold')
    
plt.xlabel("Vehicle Model ",fontdict={'fontsize':13},labelpad=18)
plt.ylabel("Battery Capacity (kWh) ",fontdict={'fontsize':13},labelpad=18)
plt.title("Average Battery Capacity By Car Model",fontdict={'fontsize':16,'fontweight':'bold'})
    
max_value = average_Battery_Capacity_by_Car_Model.select_dtypes(include='number').max().max()
plt.ylim(0,max_value + max_value * 0.2)
plt.show()
plt.clf() # ignore warnings

# %% [markdown]
# # state of charge at the start and end of charging sessions vary by vehicle model

# %%
ev_charging_df[['Vehicle Model','State of Charge (Start %)','State of Charge (End %)']]
Soc_Summary_by_Car_Models = ev_charging_df.groupby('Vehicle Model')[['State of Charge (Start %)','State of Charge (End %)']].mean().reset_index().round(2)
Soc_Summary_by_Car_Models
# Out:
#    Vehicle Model  State of Charge (Start %)  State of Charge (End %)
# 0         BMW i3                      49.82                    75.30
# 1     Chevy Bolt                      49.43                    73.97
# 2   Hyundai Kona                      50.52                    75.40
# 3    Nissan Leaf                      48.15                    76.08
# 4  Tesla Model 3                      47.81                    74.95

# %% [markdown]
# # Melt the Soc_Summar

# %%
melt_Soc_Summary_by_Car_Models = Soc_Summary_by_Car_Models.melt(id_vars='Vehicle Model',var_name='Start or End',value_name='Charging State')
melt_Soc_Summary_by_Car_Models
# Out:
#    Vehicle Model               Start or End  Charging State
# 0         BMW i3  State of Charge (Start %)           49.82
# 1     Chevy Bolt  State of Charge (Start %)           49.43
# 2   Hyundai Kona  State of Charge (Start %)           50.52
# 3    Nissan Leaf  State of Charge (Start %)           48.15
# 4  Tesla Model 3  State of Charge (Start %)           47.81
# 5         BMW i3    State of Charge (End %)           75.30
# 6     Chevy Bolt    State of Charge (End %)           73.97
# 7   Hyundai Kona    State of Charge (End %)           75.40
# 8    Nissan Leaf    State of Charge (End %)           76.08
# 9  Tesla Model 3    State of Charge (End %)           74.95

# %%
plt.figure(figsize=(12,5))

max_value = melt_Soc_Summary_by_Car_Models.select_dtypes(include='number').max().max()

bar_plot = sns.barplot(x='Vehicle Model',y='Charging State',hue='Start or End',data=melt_Soc_Summary_by_Car_Models,palette='Set1')
plt.ylim(0,max_value+max_value*0.4)
plt.xlabel("Car Models",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.ylabel("Charging State(%)",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.title("Avg Charging State Summary By Car Models",pad=20,fontdict={'fontsize':16,'fontweight':'bold'})

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', fontweight='bold',
                     xytext = (0, 9),  # Offset label slightly above the bar
                     textcoords = 'offset points')

plt.show()

# %% [markdown]
# # Average charging duration and energy consumed by different car model

# %%
ev_charging_df[['Vehicle Model','Calculated Duration Time(Hour)','Energy Consumed (kWh)']]
Avg_charging_duration_energy_consumed =   ev_charging_df.groupby('Vehicle Model')[['Calculated Duration Time(Hour)','Energy Consumed (kWh)']].mean().round(2).reset_index()
Avg_charging_duration_energy_consumed
# Out:
#    Vehicle Model  Calculated Duration Time(Hour)  Energy Consumed (kWh)
# 0         BMW i3                            2.26                  42.46
# 1     Chevy Bolt                            2.26                  40.84
# 2   Hyundai Kona                            2.24                  42.82
# 3    Nissan Leaf                            2.16                  42.51
# 4  Tesla Model 3                            2.20                  44.42

# %% [markdown]
# # Melt Avg_charging_duration_energy_consumed

# %%
melt_Avg_charging_duration_energy_consumed = Avg_charging_duration_energy_consumed.melt(id_vars='Vehicle Model',var_name='value_col',value_name='Avg_value')
melt_Avg_charging_duration_energy_consumed
# Out:
#    Vehicle Model                       value_col  Avg_value
# 0         BMW i3  Calculated Duration Time(Hour)       2.26
# 1     Chevy Bolt  Calculated Duration Time(Hour)       2.26
# 2   Hyundai Kona  Calculated Duration Time(Hour)       2.24
# 3    Nissan Leaf  Calculated Duration Time(Hour)       2.16
# 4  Tesla Model 3  Calculated Duration Time(Hour)       2.20
# 5         BMW i3           Energy Consumed (kWh)      42.46
# 6     Chevy Bolt           Energy Consumed (kWh)      40.84
# 7   Hyundai Kona           Energy Consumed (kWh)      42.82
# 8    Nissan Leaf           Energy Consumed (kWh)      42.51
# 9  Tesla Model 3           Energy Consumed (kWh)      44.42

# %%
plt.figure(figsize=(12,5))
max_value = melt_Avg_charging_duration_energy_consumed.select_dtypes(include='number').max().max()

bar_plot = sns.barplot(x='Vehicle Model',y='Avg_value',hue='value_col',data=melt_Avg_charging_duration_energy_consumed,palette='husl')
plt.xlabel("Vehicle Model",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.ylabel("Average Duration and Energy Consumed",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.title("Average Charging Duration and Energy Consumed By Car Model",fontdict={'fontsize':16,'fontweight':'bold'},pad=20)
plt.ylim(0,max_value + max_value * 0.4)

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', fontweight='bold',
                     xytext = (0, 9),  # Offset label slightly above the bar
                     textcoords = 'offset points')

plt.show()

# %% [markdown]
# # Average operating temperature for each vehicle model in the dataset during charging time

# %%
ev_charging_df[['Vehicle Model','Temperature (°C)']]
Average_Temperature_by_car_model = ev_charging_df.groupby('Vehicle Model')['Temperature (°C)'].mean().round(2).reset_index().sort_values(by='Temperature (°C)')
Average_Temperature_by_car_model
# Out:
#    Vehicle Model  Temperature (°C)
# 0         BMW i3             14.61
# 1     Chevy Bolt             14.94
# 3    Nissan Leaf             15.22
# 4  Tesla Model 3             15.28
# 2   Hyundai Kona             16.23

# %%
plt.figure(figsize=(12,4.5))

max_value = Average_Temperature_by_car_model.select_dtypes(include='number').max().max()

bar_plot = sns.barplot(x='Vehicle Model',y='Temperature (°C)',data=Average_Temperature_by_car_model,palette='viridis')

plt.xlabel("Vehicle Model",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.ylabel("Average Temperature",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.title("Average Temperature By Car Model",fontdict={'fontsize':16,'fontweight':'bold'},pad=20)

plt.ylim(0, max_value + max_value*0.1)

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', fontweight='bold',
                     xytext = (0, 9),  # Offset label slightly above the bar
                     textcoords = 'offset points')

plt.show()

# %% [markdown]
# # Average charging cost for each vehicle model in the dataset

# %%
Avg_charging_cost_by_car_model = ev_charging_df.groupby('Vehicle Model')['Charging Cost (USD)'].mean().round(2).reset_index().sort_values('Charging Cost (USD)')
Avg_charging_cost_by_car_model
# Out:
#    Vehicle Model  Charging Cost (USD)
# 0         BMW i3                20.78
# 1     Chevy Bolt                22.26
# 4  Tesla Model 3                22.58
# 2   Hyundai Kona                23.44
# 3    Nissan Leaf                23.65

# %%
plt.figure(figsize=(12,4.5))

max_value = Avg_charging_cost_by_car_model.select_dtypes(include='number').max().max()

bar_plot = sns.barplot(x='Vehicle Model',y='Charging Cost (USD)',data=Avg_charging_cost_by_car_model,palette='crest')

plt.xlabel("Vehicle Model",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.ylabel("Average Cost(USD)",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.title("Average Cost By Car Model",fontdict={'fontsize':16,'fontweight':'bold'},pad=20)

plt.ylim(0, max_value + max_value*0.2)

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', fontweight='bold',
                     xytext = (0, 9),  # Offset label slightly above the bar
                     textcoords = 'offset points')
plt.show()

# %% [markdown]
# # Analysis by User Type

# %%
distribution_User_Type = ev_charging_df['User Type'].value_counts().reset_index()
distribution_User_Type
# Out:
#                 User Type  count
# 0                Commuter    476
# 1  Long-Distance Traveler    437
# 2           Casual Driver    407

# %%
plt.figure(figsize=(5,5))
labels = distribution_User_Type['User Type']
plt.pie(distribution_User_Type['count'], labels=labels, autopct='%1.2f%%',colors=["yellow","cyan","hotpink"], explode=[0.05,0.05,0.05],shadow=True)
plt.title("Distributation Of User Type",fontdict={'fontsize':12,'fontweight':'bold'})
plt.show()

# %% [markdown]
# # Average charging cost incurred by each user type in the dataset

# %%
avg_charging_cost_by_user_type = ev_charging_df.groupby('User Type')['Charging Cost (USD)'].mean().round(2).reset_index().sort_values(by='Charging Cost (USD)')
avg_charging_cost_by_user_type
# Out:
#                 User Type  Charging Cost (USD)
# 2  Long-Distance Traveler                22.21
# 0           Casual Driver                22.68
# 1                Commuter                22.75

# %% [markdown]
# # Maximum charging cost incurred by each user type in the dataset

# %%
max_charging_cost_by_user_type = ev_charging_df.groupby('User Type')['Charging Cost (USD)'].max().round(2).reset_index().sort_values(by='Charging Cost (USD)')
max_charging_cost_by_user_type
# Out:
#                 User Type  Charging Cost (USD)
# 2  Long-Distance Traveler                60.40
# 1                Commuter                68.93
# 0           Casual Driver                69.41

# %%
plt.figure(figsize=(12,5))
max_value = max_charging_cost_by_user_type.select_dtypes(include='number').max().max()

bar_plot = sns.barplot(x='User Type',y='Charging Cost (USD)',data=max_charging_cost_by_user_type,palette='flare')
plt.xlabel("User Type",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.ylabel("Average Cost(USD)",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.title("Maximum Cost By User Type",fontdict={'fontsize':16,'fontweight':'bold'})
plt.ylim(0,max_value + max_value * 0.2)

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', fontweight='bold',
                     xytext = (0, 9),  # Offset label slightly above the bar
                     textcoords = 'offset points')

plt.show()

# %% [markdown]
# # Charger types are preferred by each user type in the dataset

# %%
distribution_of_chargerType_by_userType = (ev_charging_df.groupby('User Type')['Charger Type'].value_counts(normalize=True).unstack() * 100).round(2).reset_index()
distribution_of_chargerType_by_userType
# Out:
# Charger Type               User Type  DC Fast Charger  Level 1  Level 2
# 0                      Casual Driver            33.91    34.64    31.45
# 1                           Commuter            29.83    33.61    36.55
# 2             Long-Distance Traveler            34.32    36.16    29.52

# %% [markdown]
# # melt the distributation_of_chargerType_by_userType

# %%
melt_distribution_of_chargerType_by_userType = distribution_of_chargerType_by_userType.melt(id_vars='User Type',var_name='Charger Type',value_name='Charger Type Values')
melt_distribution_of_chargerType_by_userType
# Out:
#                 User Type     Charger Type  Charger Type Values
# 0           Casual Driver  DC Fast Charger                33.91
# 1                Commuter  DC Fast Charger                29.83
# 2  Long-Distance Traveler  DC Fast Charger                34.32
# 3           Casual Driver          Level 1                34.64
# 4                Commuter          Level 1                33.61
# 5  Long-Distance Traveler          Level 1                36.16
# 6           Casual Driver          Level 2                31.45
# 7                Commuter          Level 2                36.55
# 8  Long-Distance Traveler          Level 2                29.52

# %%
plt.figure(figsize=(12,5))
max_value = melt_distribution_of_chargerType_by_userType.select_dtypes(include='number').max().max()

bar_plot = sns.barplot(x='User Type',y='Charger Type Values',hue='Charger Type',data=melt_distribution_of_chargerType_by_userType,palette='mako')
plt.xlabel("User Type",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.ylabel("Distributation of Charger Type(%)",fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.title("Charger Type Usage Patterns Across Different User Types",fontdict={'fontsize':16,'fontweight':'bold'},pad=20)
plt.ylim(0,max_value + max_value * 0.4)

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', fontweight='bold',
                     xytext = (0, 9),  # Offset label slightly above the bar
                     textcoords = 'offset points')

plt.show()

# %% [markdown]
# # Average charging duration for each user type in the dataset

# %%
average_charging_duration_by_user_type = ev_charging_df.groupby('User Type')['Calculated Duration Time(Hour)'].mean().round(2).reset_index()
average_charging_duration_by_user_type
# Out:
#                 User Type  Calculated Duration Time(Hour)
# 0           Casual Driver                            2.28
# 1                Commuter                            2.18
# 2  Long-Distance Traveler                            2.23

# %%
plt.figure(figsize=(12,5))

colors = ['#ff9999', '#ff4d4d', '#b30000']
max_value = average_charging_duration_by_user_type.select_dtypes(include='number').max().max()
print(max_value)

bar_plot = plt.bar( average_charging_duration_by_user_type['User Type'], average_charging_duration_by_user_type['Calculated Duration Time(Hour)'],color=colors)

plt.xlabel('User Type ',fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.ylabel('Average Duration in Hour',fontdict={'fontsize':13,'fontweight':'bold'},labelpad=18)
plt.title("Average Charging Duration Time in Hour By User Type",fontdict={'fontsize':13,'fontweight':'bold'},pad=20)
plt.ylim(0,max_value+max_value*0.2)

for bar in bar_plot:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom',fontdict={'fontweight':'bold'})


plt.show()
# Out:
# 2.28
